# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# Datos extraídos del archivo
df = pd.read_excel('sesiones\\primer-parcial\\u3-regresion-lineal-simple-rls\\Base_Regresion.xlsx')

# Variables independientes y dependiente
X = df[["X1", "X2", "X3"]]
y = df["Y"]

# Agregar constante al modelo
X = sm.add_constant(X)

# Ajustar modelo
model = sm.OLS(y, X).fit()

# Mostrar resumen
print(model.summary())

# --- Gráficos de diagnóstico ---
sns.pairplot(df)
plt.show()

residuals = model.resid
fitted = model.fittedvalues

plt.scatter(fitted, residuals)
plt.axhline(0, color='red')
plt.xlabel("Valores ajustados")
plt.ylabel("Residuos")
plt.title("Residuos vs Ajustados")
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.788
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     14.90
# Date:                Tue, 09 Jun 2026   Prob (F-statistic):           0.000238
# Time:                        08:49:05   Log-Likelihood:                -131.07
# No. Observations:                  16   AIC:                             270.1
# Df Residuals:                      12   BIC:                             273.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        965.2809    499.750      1.932      0.077    -123.581    2054.143
# X1             2.8653      1.583      1.810      0.095      -0.583       6.314
# X2             6.7538     10.279      0.657      0.524     -15.643      29.150
# X3             0.2873      0.111      2.586      0.024       0.045       0.529
# ==============================================================================
# Omnibus:                        0.650   Durbin-Watson:                   2.413
# Prob(Omnibus):                  0.722   Jarque-Bera (JB):                0.300
# Skew:                           0.323   Prob(JB):                        0.861
# Kurtosis:                       2.819   Cond. No.                     9.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
