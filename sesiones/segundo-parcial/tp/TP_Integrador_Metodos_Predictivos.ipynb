# %% [markdown]
# <figure>
# <center>
# <img src='https://www.economicas.uba.ar/wp-content/uploads/2020/08/cropped-logo_FCE.png' />
# </center>
# </figure>

# %% [markdown]
# # **Universidad de Buenos Aires**
# ## **Facultad de Ciencias Económicas**
# ### **Tecnicatura en Gestión de Datos (TGAD)**
#
# ---
#
# ## **Métodos Predictivos para la Gestión**
# ### **Trabajo Práctico Integrador**
#
# ---
#
# **Dataset:** Colorado Real Estate 2026
#
# **Fecha de entrega:** [Completar]
#
# **Integrantes:**
# 1. Alexander Ballera - N° 919064
# 2. [Nombre Apellido] - N° [Registro]
# 3. [Nombre Apellido] - N° [Registro]
# 4. [Nombre Apellido] - N° [Registro]
# 5. [Nombre Apellido] - N° [Registro]
#
# ---

# %% [markdown]
# ## 📋 ÍNDICE DEL TRABAJO PRÁCTICO
#
# 1. [Carga y Configuración Inicial](#carga)
# 2. [Preguntas Obligatorias](#preguntas-obligatorias)
#    - Exploración de la Identidad y el Contexto
#    - Inventario y Tipología de Variables
#    - Identificación de "Ruido" y Variables No Informativas
#    - Definición del Problema y Encuadre del Enfoque
# 3. [i) Selección de Datos y Preprocesamiento](#preprocesamiento)
# 4. [ii) Muestreo e Inferencia](#muestreo)
# 5. [iii) Modelado Estadístico Clásico](#modelado-estadistico)
# 6. [iv) Machine Learning y Validación](#machine-learning)
# 7. [v) Conclusión Comparativa](#conclusion)
#
# ---

# %% [markdown]
# <a id="carga"></a>
# ## 🔧 SECCIÓN 0: Carga y Configuración Inicial
#
# En esta sección cargamos las librerías necesarias y el dataset.

# %% [markdown]
# ### Importar librerías necesarias

# %%
# Importar librerías para manipulación de datos

# Importar librerías para análisis estadístico

# Importar librerías para visualización

# Importar librerías para modelado estadístico

# Importar librerías para machine learning

# Configuración de warnings y visualización

# %% [markdown]
# ### Cargar el dataset

# %%
# Cargar el archivo colorado_real_estate_2026.csv

# %% [markdown]
# ### Vista preliminar de los datos

# %%
# Mostrar las primeras filas del dataset

# %% [markdown]
# ---
# <a id="preguntas-obligatorias"></a>
# ## 📝 SECCIÓN 1: Preguntas Obligatorias
#
# Esta sección responde a las preguntas obligatorias del trabajo práctico antes de iniciar el análisis formal.

# %% [markdown]
# ### 1.1 Exploración de la Identidad y el Contexto
#
# **Antes de mirar los datos, hay que entender de dónde vienen.**

# %% [markdown]
# #### ¿Cuál es la fuente de los datos?
#
# Describir: ¿Es una base gubernamental, un registro de una empresa, una simulación o una encuesta?

# %%
# Descripción de la fuente de datos

# %% [markdown]
# #### ¿Qué representa cada fila (observación)?
#
# Describir: ¿Es un cliente, un día de ventas, un paciente, una propiedad inmobiliaria?

# %%
# Descripción de lo que representa cada observación

# %% [markdown]
# #### ¿En qué período de tiempo se recolectaron?
#
# Describir: ¿Son datos actuales o históricos? ¿Podría haber factores externos que puedan haber sesgado este período?

# %%
# Análisis del período temporal de los datos

# %% [markdown]
# ---
# ### 1.2 Inventario y Tipología de Variables

# %% [markdown]
# #### ¿Cuántas variables (columnas) tienen y de qué tipo son?
#
# Clasificarlas en cualitativas (nominales/ordinales) y cuantitativas (discretas/continuas).

# %%
# Cantidad de filas y columnas

# %%
# Información sobre tipos de datos

# %%
# Clasificación de variables por tipo

# %% [markdown]
# #### ¿Cuál es la variable "Target" (objetivo)?
#
# Si es numérica → regresión. Si es categórica → clasificación.

# %%
# Identificación de la variable objetivo

# %% [markdown]
# #### ¿Qué rango tienen las variables numéricas?
#
# ¿Están en escalas muy diferentes? Esto indicará si necesitan estandarizar o normalizar.

# %%
# Rangos de variables numéricas

# %% [markdown]
# ---
# ### 1.3 Identificación de "Ruido" y Variables No Informativas
#
# **No todo lo que está en el dataset sirve para predecir.**

# %% [markdown]
# #### ¿Existen variables de identificación única?
#
# IDs, Nombres, Números de DNI. ¿Tienen algún poder predictivo o deben ser eliminadas?

# %%
# Identificar variables de ID único

# %% [markdown]
# #### ¿Hay variables con varianza cero?
#
# Una columna donde todos los registros dicen lo mismo. ¿Aporta algo al modelo si no hay variabilidad?

# %%
# Detectar variables con varianza cero o casi cero

# %% [markdown]
# #### ¿Existen variables redundantes?
#
# ¿Hay dos columnas que digan lo mismo en distinto formato? ¿Cuál conviene conservar?

# %%
# Identificar variables altamente correlacionadas (posible redundancia)

# %% [markdown]
# #### ¿Qué porcentaje de datos faltantes (NaN) tiene cada columna?
#
# Si una columna tiene el 90% de datos vacíos, ¿vale la pena intentar completarla o es mejor descartarla?

# %%
# Porcentaje de datos faltantes por columna

# %%
# Visualización de datos faltantes

# %% [markdown]
# ---
# ### 1.4 Definición del Problema y Encuadre del Enfoque
#
# **Transformar los datos en una pregunta de negocio o investigación.**

# %% [markdown]
# #### ¿Qué pregunta intentan responder con estos datos?
#
# Ejemplo: "¿Podemos predecir el precio de una propiedad basándonos en sus características?"

# %%
# Definición de la pregunta de investigación

# %% [markdown]
# #### ¿Cuál es el "dolor" o la necesidad que resuelve su modelo?
#
# ¿Quién usaría esta información y para qué tomaría una decisión basada en ella?

# %%
# Descripción del valor de negocio del modelo

# %% [markdown]
# #### ¿Cuál es su hipótesis inicial?
#
# ¿Qué variables creen, a priori, que serán las más importantes para explicar el fenómeno?

# %%
# Hipótesis sobre las variables más importantes

# %% [markdown]
# ---
# <a id="preprocesamiento"></a>
# ## 🧹 SECCIÓN 2: i) Selección de Datos y Preprocesamiento (Unidad 2)

# %% [markdown]
# ### 2.1 Selección del Dataset
#
# El dataset seleccionado es **colorado_real_estate_2026.csv** con información de propiedades inmobiliarias en Colorado.
#
# **Requisitos:**
# - ✅ Mínimo 10,000 observaciones
# - ✅ No menos de 10 variables para analizar
# - ✅ Variable objetivo definida (numérica para regresión o categórica para clasificación)

# %%
# Verificar que el dataset cumple con los requisitos mínimos

# %% [markdown]
# ---
# ### 2.2 Limpieza de Datos
#
# En esta sección identificamos y tratamos los problemas de calidad de datos.

# %% [markdown]
# #### 2.2.1 Identificación de valores faltantes

# %%
# Identificar valores faltantes por columna

# %%
# Visualizar el patrón de valores faltantes

# %% [markdown]
# #### 2.2.2 Tratamiento de valores faltantes
#
# Decisión: ¿imputación o eliminación? Justificar la estrategia elegida.

# %%
# Estrategia de tratamiento de valores faltantes
# Opción 1: Eliminación (listwise deletion)
# Opción 2: Imputación por media/mediana/moda
# Opción 3: Imputación avanzada (KNN, regresión)

# %% [markdown]
# #### 2.2.3 Detección de valores atípicos (Outliers)
#
# **Método 1: Boxplots (visualización)**

# %%
# Boxplots para detectar outliers visualmente en variables numéricas

# %% [markdown]
# **Método 2: Regla de Tukey (RIQ)**
#
# Outlier si: `x < Q1 - 1.5*RIQ` o `x > Q3 + 1.5*RIQ`

# %%
# Función para detectar outliers con regla de Tukey

# %%
# Aplicar detección de outliers a variables numéricas principales

# %% [markdown]
# **Método 3: Z-score**
#
# Outlier si: `|z-score| > 3`

# %%
# Detección de outliers con Z-score

# %% [markdown]
# #### 2.2.4 Tratamiento de outliers
#
# Decisión: ¿conservar, eliminar o transformar? Justificar.

# %%
# Estrategia de tratamiento de outliers

# %% [markdown]
# #### 2.2.5 Detección de duplicados

# %%
# Identificar registros duplicados

# %%
# Eliminar duplicados si existen

# %% [markdown]
# #### 2.2.6 Resolución de inconsistencias lógicas
#
# Verificar coherencia entre variables relacionadas.

# %%
# Detectar y resolver inconsistencias lógicas

# %% [markdown]
# ---
# ### 2.3 Análisis Descriptivo
#
# Realizar un estudio analítico descriptivo completo de las variables.

# %% [markdown]
# #### 2.3.1 Resumen estadístico general

# %%
# Resumen estadístico con .describe()

# %% [markdown]
# #### 2.3.2 Medidas de Tendencia Central

# %% [markdown]
# ##### Media (promedio aritmético)

# %%
# Media de las variables numéricas principales

# %% [markdown]
# ##### Mediana (percentil 50)

# %%
# Mediana de las variables numéricas principales

# %% [markdown]
# ##### Moda (valor más frecuente)

# %%
# Moda de las variables

# %% [markdown]
# #### 2.3.3 Medidas de Dispersión

# %% [markdown]
# ##### Varianza

# %%
# Varianza de las variables numéricas

# %% [markdown]
# ##### Desvío estándar

# %%
# Desvío estándar de las variables numéricas

# %% [markdown]
# ##### Rango

# %%
# Rango (máximo - mínimo)

# %% [markdown]
# ##### Rango Intercuartílico (RIQ)

# %%
# Rango intercuartílico (Q3 - Q1)

# %% [markdown]
# ##### Coeficiente de Variación (CV)

# %%
# Coeficiente de variación (desvío/media * 100)

# %% [markdown]
# #### 2.3.4 Medidas de Forma

# %% [markdown]
# ##### Asimetría (Skewness)

# %%
# Coeficiente de asimetría de Fisher (g1)

# %% [markdown]
# ##### Curtosis (Kurtosis)

# %%
# Curtosis

# %% [markdown]
# #### 2.3.5 Percentiles y Cuartiles

# %%
# Percentiles relevantes (P10, P25, P50, P75, P90)

# %% [markdown]
# #### 2.3.6 Histogramas de Distribución
#
# Visualizar la distribución de las variables numéricas principales.

# %%
# Histogramas de las variables numéricas clave

# %% [markdown]
# #### 2.3.7 Análisis de Distribución por Variable Objetivo

# %%
# Distribución de la variable objetivo

# %% [markdown]
# #### 2.3.8 Matriz de Correlación
#
# Analizar las relaciones lineales entre variables numéricas.

# %% [markdown]
# ##### Correlación de Pearson

# %%
# Matriz de correlación de Pearson

# %%
# Visualización de la matriz de correlación con heatmap

# %% [markdown]
# ##### Correlación de Spearman (más robusta ante outliers)

# %%
# Matriz de correlación de Spearman

# %% [markdown]
# #### 2.3.9 Interpretación de Resultados Descriptivos
#
# **Celda de texto narrativa:** Redactar las conclusiones del análisis descriptivo, destacando hallazgos relevantes, distribuciones asimétricas, correlaciones fuertes, etc.

# %%
# Generar un reporte resumen del análisis descriptivo

# %% [markdown]
# ---
# <a id="muestreo"></a>
# ## 📊 SECCIÓN 3: ii) Muestreo e Inferencia (Unidad 1)

# %% [markdown]
# ### 3.1 Extracción de la Muestra
#
# Sobre la base total, extraer una **muestra aleatoria simple de n = 750 observaciones**.

# %%
# Extracción de muestra aleatoria simple sin reemplazo (n=750)

# %%
# Verificar tamaño de la muestra

# %% [markdown]
# ---
# ### 3.2 Validación de la Muestra
#
# Justificar por qué la muestra es representativa. Comparar la **media y varianza** de la variable objetivo entre la muestra y la población original.

# %% [markdown]
# #### 3.2.1 Comparación de estadísticos: Media

# %%
# Comparar media de la variable objetivo: población vs muestra

# %% [markdown]
# #### 3.2.2 Comparación de estadísticos: Varianza

# %%
# Comparar varianza de la variable objetivo: población vs muestra

# %% [markdown]
# #### 3.2.3 Comparación de estadísticos: Desvío estándar

# %%
# Comparar desvío estándar: población vs muestra

# %% [markdown]
# #### 3.2.4 Comparación de distribuciones
#
# Visualizar la distribución de la variable objetivo en ambos datasets.

# %%
# Histogramas comparativos: población vs muestra

# %% [markdown]
# #### 3.2.5 Tabla comparativa de estadísticos
#
# Resumen de todas las comparaciones.

# %%
# Tabla resumen: población vs muestra

# %% [markdown]
# #### 3.2.6 Conclusión sobre representatividad
#
# **Celda de texto narrativa:** Justificar si la muestra es representativa de la población basándose en los resultados anteriores.

# %%
# Cálculo de diferencias porcentuales

# %% [markdown]
# ---
# <a id="modelado-estadistico"></a>
# ## 📈 SECCIÓN 4: iii) Modelado Estadístico Clásico (Unidades 3, 4 y 5)

# %% [markdown]
# ### Definición del Enfoque
#
# Dependiendo de la naturaleza de la variable objetivo:
# - **Opción A (Regresión):** Variable continua → Regresión Lineal
# - **Opción B (Clasificación):** Variable categórica → Regresión Logística
#
# **Enfoque seleccionado:** [Completar: Regresión o Clasificación]

# %%
# Definir las variables del modelo (X: features, y: target)

# %% [markdown]
# ---
# ### 4.1 Modelo con Muestra (n=750)
#
# Ajustar el modelo utilizando **únicamente la muestra de 750 registros**.

# %% [markdown]
# #### 4.1.1 Preparación de datos - Muestra

# %%
# Preparar variables X (features) e y (target) para la muestra

# %% [markdown]
# #### 4.1.2 Ajuste del modelo - Muestra
#
# **Para Regresión:** Regresión Lineal con statsmodels

# %%
# Ajustar modelo de Regresión Lineal con la muestra

# %% [markdown]
# **Para Clasificación:** Regresión Logística con statsmodels

# %%
# Ajustar modelo de Regresión Logística con la muestra (si aplica)

# %% [markdown]
# #### 4.1.3 Resumen del modelo - Muestra

# %%
# Mostrar resumen completo del modelo (coeficientes, p-valores, R²/Accuracy)

# %% [markdown]
# #### 4.1.4 Interpretación de coeficientes - Muestra
#
# **Celda de texto narrativa:** Interpretar los coeficientes estimados, su significado práctico y su significatividad estadística.

# %%
# Extraer y visualizar coeficientes del modelo

# %% [markdown]
# #### 4.1.5 Evaluación del ajuste - Muestra
#
# **Para Regresión:** R², R² ajustado, AIC, BIC

# %%
# Métricas de bondad de ajuste para regresión

# %% [markdown]
# **Para Clasificación:** Accuracy, Matriz de Confusión

# %%
# Métricas de clasificación (si aplica)

# %% [markdown]
# #### 4.1.6 Diagnóstico del modelo - Muestra
#
# Gráficos de residuos vs valores ajustados.

# %%
# Gráfico de residuos vs valores ajustados

# %% [markdown]
# ---
# ### 4.2 Modelo con Base de Datos Total
#
# Repetir el análisis utilizando la **base de datos completa**.

# %% [markdown]
# #### 4.2.1 Preparación de datos - Base Total

# %%
# Preparar variables X (features) e y (target) para la base total

# %% [markdown]
# #### 4.2.2 Ajuste del modelo - Base Total
#
# **Para Regresión:** Regresión Lineal con statsmodels

# %%
# Ajustar modelo de Regresión Lineal con base total

# %% [markdown]
# **Para Clasificación:** Regresión Logística con statsmodels

# %%
# Ajustar modelo de Regresión Logística con base total (si aplica)

# %% [markdown]
# #### 4.2.3 Resumen del modelo - Base Total

# %%
# Mostrar resumen completo del modelo

# %% [markdown]
# #### 4.2.4 Interpretación de coeficientes - Base Total
#
# **Celda de texto narrativa:** Interpretar los coeficientes estimados.

# %%
# Extraer y visualizar coeficientes del modelo

# %% [markdown]
# #### 4.2.5 Evaluación del ajuste - Base Total

# %%
# Métricas de bondad de ajuste

# %% [markdown]
# #### 4.2.6 Diagnóstico del modelo - Base Total

# %%
# Gráfico de residuos vs valores ajustados

# %% [markdown]
# ---
# ### 4.3 Comparación Crítica: Muestra vs Base Total
#
# Evaluar las diferencias en:
# - **Coeficientes estimados (β)**
# - **Errores estándar**
# - **Bondad de ajuste (R² o Accuracy)**
# - **Significatividad de los regresores (p-valores)**

# %% [markdown]
# #### 4.3.1 Comparación de coeficientes

# %%
# Tabla comparativa de coeficientes: Muestra vs Base Total

# %% [markdown]
# #### 4.3.2 Comparación de errores estándar

# %%
# Comparación de errores estándar

# %% [markdown]
# #### 4.3.3 Comparación de bondad de ajuste

# %%
# Comparación de R² (o Accuracy) entre ambos modelos

# %% [markdown]
# #### 4.3.4 Comparación de significatividad (p-valores)

# %%
# Tabla de p-valores: Muestra vs Base Total

# %% [markdown]
# #### 4.3.5 Visualización de comparaciones

# %%
# Gráficos comparativos de coeficientes

# %% [markdown]
# #### 4.3.6 Discusión: Impacto del tamaño de la muestra
#
# **Celda de texto narrativa:** Discutir cómo el tamaño de la muestra afectó:
# - La estabilidad de los coeficientes
# - Los errores estándar
# - La significatividad de los regresores
# - La capacidad predictiva del modelo

# %%
# Análisis cuantitativo del impacto del tamaño muestral

# %% [markdown]
# ---
# <a id="machine-learning"></a>
# ## 🤖 SECCIÓN 5: iv) Machine Learning y Validación (Unidad 6)
#
# Aplicar técnicas de aprendizaje supervisado sobre la **base total**.

# %% [markdown]
# ### 5.1 División de Datos: Train y Test
#
# Separar el dataset en conjuntos de **Entrenamiento (Train)** y **Prueba (Test)**.

# %%
# División 80% Train - 20% Test

# %%
# Verificar tamaños de los conjuntos

# %% [markdown]
# ---
# ### 5.2 Implementación de Algoritmos
#
# Entrenar **al menos dos algoritmos** de Machine Learning.
#
# **Opciones para Regresión:**
# - Decision Tree Regressor
# - Random Forest Regressor
# - k-NN Regressor
# - Gradient Boosting Regressor
#
# **Opciones para Clasificación:**
# - Decision Tree Classifier
# - Random Forest Classifier
# - k-NN Classifier
# - Gradient Boosting Classifier

# %% [markdown]
# #### 5.2.1 Algoritmo 1: [Nombre del algoritmo]
#
# **Ejemplo: Decision Tree**

# %%
# Importar el algoritmo

# %%
# Entrenar modelo 1

# %%
# Predicciones en conjunto de prueba

# %% [markdown]
# #### 5.2.2 Algoritmo 2: [Nombre del algoritmo]
#
# **Ejemplo: Random Forest**

# %%
# Importar el algoritmo

# %%
# Entrenar modelo 2

# %%
# Predicciones en conjunto de prueba

# %% [markdown]
# #### 5.2.3 Algoritmo 3 (Opcional): [Nombre del algoritmo]

# %%
# Entrenar modelo 3 (opcional)

# %% [markdown]
# ---
# ### 5.3 Evaluación de Métricas
#
# Evaluar el desempeño de cada algoritmo con las métricas apropiadas.

# %% [markdown]
# #### 5.3.1 Métricas para Regresión
#
# **Métricas:** MAE, MSE, RMSE, R²

# %% [markdown]
# ##### Modelo 1: Métricas de Regresión

# %%
# Calcular MAE, MSE, RMSE, R² para Modelo 1

# %% [markdown]
# ##### Modelo 2: Métricas de Regresión

# %%
# Calcular MAE, MSE, RMSE, R² para Modelo 2

# %% [markdown]
# #### 5.3.2 Métricas para Clasificación
#
# **Métricas:** Matriz de Confusión, Precisión, Recall, F1-Score, ROC-AUC

# %% [markdown]
# ##### Modelo 1: Matriz de Confusión

# %%
# Matriz de confusión para Modelo 1 (si aplica clasificación)

# %% [markdown]
# ##### Modelo 1: Reporte de Clasificación

# %%
# Precision, Recall, F1-Score para Modelo 1

# %% [markdown]
# ##### Modelo 2: Matriz de Confusión

# %%
# Matriz de confusión para Modelo 2 (si aplica clasificación)

# %% [markdown]
# ##### Modelo 2: Reporte de Clasificación

# %%
# Precision, Recall, F1-Score para Modelo 2

# %% [markdown]
# ##### Curva ROC-AUC

# %%
# Curva ROC para ambos modelos (si aplica clasificación)

# %% [markdown]
# #### 5.3.3 Tabla Comparativa de Métricas
#
# Comparar el desempeño de todos los modelos de ML.

# %%
# Tabla resumen de métricas: comparación entre modelos

# %% [markdown]
# ---
# ### 5.4 Optimización y Control de Overfitting
#
# Mencionar si existió **sobreajuste (overfitting)** y cómo se controló.

# %% [markdown]
# #### 5.4.1 Detección de Overfitting
#
# Comparar desempeño en Train vs Test.

# %%
# Evaluar modelos en conjunto de entrenamiento

# %%
# Comparar métricas: Train vs Test

# %% [markdown]
# #### 5.4.2 Validación Cruzada (Cross-Validation)

# %%
# Aplicar validación cruzada (k-fold)

# %% [markdown]
# #### 5.4.3 Ajuste de Hiperparámetros
#
# **Ejemplo:** GridSearchCV o RandomizedSearchCV

# %%
# Grid Search para encontrar mejores hiperparámetros

# %% [markdown]
# #### 5.4.4 Modelo Final Optimizado

# %%
# Entrenar modelo final con mejores parámetros

# %%
# Evaluar modelo final optimizado

# %% [markdown]
# #### 5.4.5 Interpretación de la optimización
#
# **Celda de texto narrativa:** Discutir cómo la optimización mejoró (o no) el desempeño del modelo.

# %%
# Comparación antes y después de la optimización

# %% [markdown]
# ---
# ### 5.5 Importancia de Variables (Feature Importance)
#
# Analizar qué variables fueron más importantes para los modelos de ML.

# %%
# Importancia de variables para Random Forest / Decision Tree

# %%
# Visualización de importancia de variables

# %% [markdown]
# ---
# <a id="conclusion"></a>
# ## 🎯 SECCIÓN 6: v) Conclusión Comparativa
#
# El informe final debe cerrar con una comparación entre los diferentes enfoques.

# %% [markdown]
# ### 6.1 Resumen de Resultados
#
# Tabla comparativa de **todos los modelos** (estadísticos y ML).

# %%
# Tabla resumen final: Modelo Estadístico vs Modelos de ML

# %% [markdown]
# ---
# ### 6.2 Modelo Estadístico Clásico vs Machine Learning

# %% [markdown]
# #### 6.2.1 Interpretabilidad vs Capacidad Predictiva
#
# **Celda de texto narrativa:**
# - **Modelo Estadístico:** Enfocado en la interpretación de parámetros. ¿Los coeficientes son interpretables? ¿Se cumplen los supuestos del modelo?
# - **Modelo de ML:** Enfocado en la capacidad predictiva. ¿Qué tan precisas son las predicciones? ¿Es un "black box"?

# %%
# Comparación cuantitativa: R² o Accuracy

# %% [markdown]
# #### 6.2.2 Complejidad del Modelo

# %%
# Análisis de complejidad: número de parámetros, profundidad del árbol, etc.

# %% [markdown]
# #### 6.2.3 Velocidad de Entrenamiento e Inferencia

# %%
# Comparar tiempos de entrenamiento

# %% [markdown]
# ---
# ### 6.3 Recomendación para Entorno de Producción
#
# **Celda de texto narrativa:** Discutir cuál modelo elegirían para un entorno de producción y **por qué**.
#
# Considerar:
# - **Precisión:** ¿Qué modelo tiene mejor desempeño predictivo?
# - **Interpretabilidad:** ¿Es importante explicar las predicciones?
# - **Complejidad:** ¿Qué tan fácil es mantener el modelo?
# - **Costo computacional:** ¿El modelo es eficiente?
# - **Robustez:** ¿El modelo se mantiene estable con nuevos datos?

# %%
# Análisis de trade-offs para decisión final

# %% [markdown]
# ---
# ### 6.4 Limitaciones del Estudio
#
# **Celda de texto narrativa:** Discutir las limitaciones del análisis:
# - Variables no incluidas que podrían mejorar el modelo
# - Posibles sesgos en los datos
# - Supuestos no verificados
# - Restricciones del tamaño de la muestra

# %%
# Análisis de limitaciones identificadas

# %% [markdown]
# ---
# ### 6.5 Recomendaciones para Trabajo Futuro
#
# **Celda de texto narrativa:** Sugerencias para mejorar el análisis:
# - Variables adicionales a incluir
# - Técnicas de feature engineering
# - Modelos alternativos a probar
# - Estrategias de validación más robustas

# %%
# Ideas para mejoras futuras

# %% [markdown]
# ---
# ## 📚 Referencias y Bibliografía
#
# **Celda de texto narrativa:** Listar las fuentes consultadas:
# - Documentación de librerías (Pandas, Scikit-learn, Statsmodels)
# - Material de clase (Taller y Laboratorio de Datos)
# - Papers o artículos académicos
# - Fuentes de datos

# %%
# Enlaces a documentación y recursos utilizados

# %% [markdown]
# ---
# ## ✅ Checklist de Entregables
#
# **Verificar antes de entregar:**
#
# - [ ] Notebook autosuficiente y reproducible
# - [ ] Código comentado y bien estructurado
# - [ ] Celdas de texto explicando cada paso
# - [ ] Gráficos con interpretación inmediatamente después
# - [ ] Todas las secciones completas:
#   - [ ] Preprocesamiento y limpieza
#   - [ ] Análisis descriptivo completo
#   - [ ] Muestreo y validación
#   - [ ] Modelo estadístico (muestra y total)
#   - [ ] Comparación estadística
#   - [ ] Machine Learning (mínimo 2 algoritmos)
#   - [ ] Métricas de evaluación
#   - [ ] Conclusiones comparativas
# - [ ] Respuestas a todas las preguntas obligatorias
# - [ ] Referencias y bibliografía
# - [ ] Revisión de ortografía y redacción
#
# ---

# %% [markdown]
# ---
# ## 📝 Notas Finales
#
# **Fecha de última modificación:** [Completar]
#
# **Próximos pasos:**
# 1. Completar todas las celdas de código
# 2. Ejecutar el notebook completo de principio a fin
# 3. Verificar que no hay errores
# 4. Revisar redacción y narrativa
# 5. Preparar presentación oral
#
# **Recordatorio para la defensa oral:**
# - No leer código durante la exposición
# - Enfocarse en hallazgos y conclusiones
# - Preparar respuestas para preguntas técnicas sobre metodología
# - Dominar la interpretación de los resultados
#
# ---
#
# **¡Éxito en el Trabajo Práctico!** 🎓
